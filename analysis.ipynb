# %% [markdown]
# # Анализ продаж за 2023 год
#
# В этом ноутбуке мы проведем предварительный анализ данных о продажах.
# **Автор:** Дата-сайентист
# **Дата:** 24 октября 2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Настройка отображения графиков
# %matplotlib inline
plt.style.use('seaborn-v0_8')

# %%
# Генерация тестовых данных
dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
sales = np.random.randint(100, 500, size=100)
regions = np.random.choice(['North', 'South', 'East', 'West'], size=100)

df = pd.DataFrame({
    'date': dates,
    'sales': sales,
    'region': regions
})

# %%
# Просмотр первых строк датафрейма
df.head(1)
# Out:
#         date  sales region
# 0 2023-01-01    342  North

# %%
# Общая информация о данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    100 non-null    datetime64[ns]
#  1   sales   100 non-null    int64
#  2   region  100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.5+ KB

# %%
# Группировка по регионам
region_sales = df.groupby('region')['sales'].sum().sort_values(ascending=False)

# Построение графика
plt.figure(figsize=(10, 6))
region_sales.plot(kind='bar', color='skyblue')
plt.title('Продажи по регионам')
plt.xlabel('Регион')
plt.ylabel('Общая сумма')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# ## Выводы
#
# 1. Данные успешно загружены и обработаны.
# 2. Наибольший объем продаж наблюдается в регионе **North**.
# 3. Рекомендуется провести углубленный анализ сезонности.
#
# ---
# *Конец отчета*
